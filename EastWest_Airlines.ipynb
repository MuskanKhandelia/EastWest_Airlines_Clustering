# %%
# Importing all the required libraries 

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %% [markdown]
# ## Data Collection

# %%
path = 'https://raw.githubusercontent.com/MuskanKhandelia/EastWest_Airlines_Clustering/main/EastWestAirlines.xlsx'

data = pd.read_excel(path, sheet_name = 'data')
original_data = data.copy()
data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %% [markdown]
# ## Data Preparation

# %%
data.shape
# Out:
# (3999, 12)

# %%
data.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
data.rename(columns = {'ID#':'Id','Award?':'Award'}, inplace = True)
data.columns
# Out:
# Index(['Id', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award'],
#       dtype='object')

# %%
data.set_index('Id', inplace = True)
data.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# Id
# 1     28143           0          1          1          1          174
# 2     19244           0          1          1          1          215
# 3     41354           0          1          1          1         4123
# 4     14776           0          1          1          1          500
# 5     97752           0          4          1          1        43300
#
#     Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# Id
# 1             1                  0                0               7000      0
# 2             2                  0                0               6968      0
# 3             4                  0                0               7034      0
# 4             1                  0                0               6952      0
# 5            26               2077                4               6935      1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3999 entries, 1 to 4021
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award              3999 non-null   int64
# dtypes: int64(11)
# memory usage: 374.9 KB

# %%
data.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
scaler = MinMaxScaler()
data = pd.DataFrame(scaler.fit_transform(data), columns = data.columns)
data.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0     0.011628           0.000000         0.000000           0.843742    0.0
# 1     0.023256           0.000000         0.000000           0.839884    0.0
# 2     0.046512           0.000000         0.000000           0.847842    0.0
# 3     0.011628           0.000000         0.000000           0.837955    0.0
# 4     0.302326           0.067398         0.075472           0.835905    1.0

# %%
wcss = []

for i in range(1,14):
    km = KMeans(n_clusters = i, n_init = 'auto', random_state = 0)
    km.fit(data)
    wcss.append(km.inertia_)
    
wcss
# Out:
# [1830.793212858411,
#  823.6756984125209,
#  635.2160678747744,
#  436.70885761932567,
#  409.8419845470978,
#  324.26256029101523,
#  311.96305603723505,
#  272.82761144254084,
#  245.24277703138273,
#  228.48943200048836,
#  219.05944357529617,
#  208.24672886626644,
#  199.40675811217295]

# %%
sns.lineplot(x = range(1,14), y = wcss, marker = 'o')
# Out:
# <Axes: >

# %% [markdown]
# ## Model Fitting

# %%
km = KMeans(n_clusters = 6, n_init = 'auto', random_state = 0)
km.fit(data)
data['Cluster'] = km.predict(data)
data.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0     0.011628           0.000000         0.000000           0.843742    0.0
# 1     0.023256           0.000000         0.000000           0.839884    0.0
# 2     0.046512           0.000000         0.000000           0.847842    0.0
# 3     0.011628           0.000000         0.000000           0.837955    0.0
# 4     0.302326           0.067398         0.075472           0.835905    1.0
#
#    Cluster
# 0        5
# 1        5
# 2        5
# 3        5
# 4        2

# %%
km.inertia_
# Out:
# 324.26256029101523

# %%
cluster_means = data.groupby('Cluster').mean()
cluster_means
# Out:
#           Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# Cluster
# 0        0.048995    0.026054   0.039004   0.016345   0.002229     0.033564
# 1        0.019414    0.008444   0.017684   0.008236   0.001696     0.012305
# 2        0.063535    0.017791   0.728960   0.000619   0.006498     0.172970
# 3        0.080881    0.004893   0.676230   0.000000   0.006557     0.129020
# 4        0.058191    0.008244   0.616613   0.001597   0.004792     0.109280
# 5        0.029282    0.008065   0.030530   0.009793   0.000288     0.013149
#
#          Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# Cluster
# 0           0.121825           0.033427         0.059407           0.522892
# 1           0.071784           0.006907         0.011390           0.239981
# 2           0.234904           0.023160         0.040421           0.586139
# 3           0.199581           0.007164         0.012929           0.732205
# ...
